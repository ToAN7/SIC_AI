# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://vnexpress.net/', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://vnexpress.net/")
# Out:
# Co tat ca 286 den tu https://vnexpress.net/

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  # fillter out only-html link
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong vnexpress")
# Out:
# Xuat hien 143 bai bao trong vnexpress

# %%
star = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  vnex_url.download()
  vnex_url.parse()
  row = [vnex_url.meta_data['lastmod'],vnex_url.text,vnex_url.url]
  star = np.append(star, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(star,(star.size//3,3))
filename = 'vnex_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                           Date  \
# 0    2024-07-21T09:00:00+07:00
# 1    2024-07-20T18:04:00+07:00
# 2    2024-07-21T08:46:37+07:00
# 3    2024-07-21T08:30:50+07:00
# 4    2024-07-21T10:05:04+07:00
# ..                         ...
# 138  2024-02-28T21:37:42+07:00
# 139  2024-02-26T00:00:00+07:00
# 140  2024-02-25T14:24:02+07:00
# 141  2024-02-24T09:27:39+07:00
# 142  2024-07-20T19:47:26+07:00
#
#                                                Content  \
# 0    Truyền thông thế giới đồng loạt đưa tin về sự ...
# 1    Tang lễ Tổng bí thư Nguyễn Phú Trọng sẽ được t...
# 2    Sáng 21/7, áp thấp nhiệt đới trên Biển Đông đã...
# 3    Ngoài các tuyến cũ đã quy hoạch, thành phố sẽ ...
# 4    Ông Trump tuyên bố đã lãnh một viên đạn "vì nề...
# ..                                                 ...
# 138  Hà NộiChủ tịch FLC Trịnh Văn Quyết và đồng phạ...
# 139  Hà NộiCựu chủ tịch FLC Trịnh Văn Quyết cùng nh...
# 140  Ông Trần Đắc Sinh bị cáo buộc khi là Chủ tịch ...
# 141  7 người của Vụ Giám sát công ty đại chúng, Tru...
# 142  Luật Đất đai 2024, có hiệu lực từ ngày 1/8, tr...
#
#                                                 Source
# 0    https://vnexpress.net/bao-chi-quoc-te-dua-tin-...
# 1    https://vnexpress.net/tong-bi-thu-nguyen-phu-t...
# 2    https://vnexpress.net/ap-thap-nhiet-doi-manh-l...
# 3    https://vnexpress.net/tp-hcm-tim-huong-chong-k...
# 4    https://vnexpress.net/ong-trump-toi-da-lanh-da...
# ..                                                 ...
# 138  https://vnexpress.net/5-nam-tao-song-co-phieu-...
# 139  https://vnexpress.net/cuu-chu-tich-flc-trinh-v...
# 140  https://vnexpress.net/cach-lanh-dao-hose-giup-...
# 141  https://vnexpress.net/7-can-bo-chung-khoan-lie...
# 142  https://vnexpress.net/trong-tai-thuong-mai-sap...
#
# [143 rows x 3 columns]
