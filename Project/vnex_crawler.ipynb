# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://vnexpress.net/', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://vnexpress.net/")
# Out:
# Co tat ca 1714 den tu https://vnexpress.net/

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  # fillter out only-html link
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong vnexpress")
# Out:
# Xuat hien 851 bai bao trong vnexpress

# %%
star = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  vnex_url.download()
  vnex_url.parse()
  row = [vnex_url.meta_data['lastmod'],vnex_url.text,vnex_url.url]
  star = np.append(star, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(star,(star.size//3,3))
filename = 'vnex_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                           Date  \
# 0    2024-07-24T15:01:51+07:00
# 1    2024-07-24T14:11:46+07:00
# 2    2024-07-24T14:01:14+07:00
# 3    2024-07-24T00:00:00+07:00
# 4    2024-07-24T16:24:36+07:00
# ..                         ...
# 846  2024-07-19T10:37:07+07:00
# 847  2024-07-19T06:00:00+07:00
# 848  2024-07-19T00:20:56+07:00
# 849  2024-07-19T00:00:00+07:00
# 850  2024-07-18T19:29:00+07:00
#
#                                                Content  \
# 0    Các lãnh đạo cấp cao ASEAN ra tuyên bố chun...
# 1    Cầu vượt sẽ được xây dựng tại các nút giao lớn...
# 2    Cho rằng kết quả nửa đầu năm tốt hơn kỳ vọng, ...
# 3    Sau hai năm gặp lại, tôi thấy anh gầy rộc, già...
# 4    Video mới xuất hiện cho thấy thi thể nghi phạm...
# ..                                                 ...
# 846  Giữa nắng nóng cực điểm, nhiều người Hàn Quốc ...
# 847  Bị gia đình giục cưới, tuyên bố Tết phải có bạ...
# 848  Thanh HóaPít Văn Nương 11 tuổi, học hết lớp 4 ...
# 849  Thông qua quỹ Hy vọng, FPT Long Châu đã hỗ trợ...
# 850  Chọn sai món trong bữa ăn để bàn chuyện công v...
#
#                                                 Source
# 0    https://vnexpress.net/lanh-dao-cap-cao-asean-r...
# 1    https://vnexpress.net/de-xuat-dau-tu-4-nut-gia...
# 2    https://vnexpress.net/hsbc-nang-du-bao-tang-tr...
# 3    https://vnexpress.net/do-no-vi-gia-dat-4773470...
# 4    https://vnexpress.net/my-cong-bo-video-hien-tr...
# ..                                                 ...
# 846  https://vnexpress.net/nguoi-han-quoc-co-ro-tro...
# 847  https://vnexpress.net/thue-ban-trai-ra-mat-gia...
# 848  https://vnexpress.net/nhung-dua-tre-cam-diec-o...
# 849  https://vnexpress.net/fpt-long-chau-tai-tro-ho...
# 850  https://vnexpress.net/nhung-mon-khong-nen-goi-...
#
# [851 rows x 3 columns]
