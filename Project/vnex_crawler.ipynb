# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://vnexpress.net/', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://vnexpress.net/")
# Out:
# Co tat ca 1721 den tu https://vnexpress.net/

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  # fillter out only-html link
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong vnexpress")
# Out:
# Xuat hien 855 bai bao trong vnexpress

# %%
star = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  vnex_url.download()
  vnex_url.parse()
  row = [vnex_url.meta_data['lastmod'],vnex_url.text,vnex_url.url]
  star = np.append(star, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(star,(star.size//3,3))
filename = 'vnex_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                           Date  \
# 0    2024-07-28T17:49:41+07:00
# 1    2024-07-28T19:00:00+07:00
# 2    2024-07-28T20:02:23+07:00
# 3    2024-07-27T12:00:00+07:00
# 4    2024-07-28T16:43:03+07:00
# ..                         ...
# 850  2024-07-25T19:00:00+07:00
# 851  2024-07-25T17:00:00+07:00
# 852  2024-07-25T13:00:00+07:00
# 853  2024-07-25T09:00:00+07:00
# 854  2024-07-25T00:00:00+07:00
#
#                                                Content  \
# 0    PhápXạ thủ của Việt Nam thi đấu ổn định và liê...
# 1    Chặng khởi đầu cuộc đua vào Nhà Trắng đang diễ...
# 2    Tình huống diễn tập là tại dây chuyền chiếu xạ...
# 3    “Trượt đại học bây giờ khó như sút hỏng một cú...
# 4    Từ đêm 28/7, vùng núi phía bắc mưa phổ biến 70...
# ..                                                 ...
# 850  Bạn gái thừa nhận đang nói chuyện với người kh...
# 851  Chồng tôi bảo mẹ chồng khó khăn, giận chú rồi ...
# 852  Em nói thẳng sẽ không sinh con nữa, điều đó là...
# 853  Số tiền tôi cho ba mẹ mượn, tôi trả nợ trong b...
# 854  Tôi đã tìm thấy hạnh phúc thực sự, không phải ...
#
#                                                 Source
# 0    https://vnexpress.net/xa-thu-trinh-thu-vinh-lo...
# 1    https://vnexpress.net/tuan-trang-mat-tranh-cu-...
# 2    https://vnexpress.net/dien-tap-ung-pho-su-co-b...
# 3    https://vnexpress.net/hoc-them-vao-truong-top-...
# 4    https://vnexpress.net/mien-bac-se-co-noi-mua-t...
# ..                                                 ...
# 850  https://vnexpress.net/cu-chan-la-ban-gai-nhan-...
# 851  https://vnexpress.net/chung-toi-bi-me-chong-ma...
# 852  https://vnexpress.net/ban-gai-chi-muon-la-tri-...
# 853  https://vnexpress.net/me-am-tham-the-chap-nha-...
# 854  https://vnexpress.net/ban-gai-giup-toi-tu-tin-...
#
# [855 rows x 3 columns]
