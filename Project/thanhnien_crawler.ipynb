# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://thanhnien.vn', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://thanhnien.vn")
# Out:
# Co tat ca 186 den tu https://thanhnien.vn

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong thanhnien")
# Out:
# Xuat hien 186 bai bao trong thanhnien

# %%
head = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  try:
    vnex_url.download()
    vnex_url.parse()
    date = vnex_url.meta_data['article']['published_time']
  except Exception:
    pass
  else:
    row = [date,vnex_url.text,vnex_url.url]
    head = np.append(head, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(head,(head.size//3,3))
filename = 'thanhnien_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                     Date                                            Content  \
# 0    2024-07-20T16:14:00  Chia sẻ với báo chí Việt Nam, Đại sứ Trung Quố...
# 1    2024-07-20T15:58:00  Khâm phục về những đóng góp quan trọng, m...
# 2    2024-07-20T14:05:00  Không khoan nhượng với tham nhũng\r\n\r\nCần p...
# 3    2024-07-20T13:09:00  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nTheo thông cáo...
# 4    2024-07-20T12:39:00  Trong số các lãnh đạo cao nhất của Đảng và Nhà...
# ..                   ...                                                ...
# 178  2024-07-19T23:48:00  Jennifer Lopez và Ben Affleck hiện không ở bên...
# 179  2024-07-17T22:18:00  Thanh Hằng chia sẻ món quà của Chủ tịch Miss U...
# 180  2022-04-05T15:10:39  chụp màn hình\r\n\r\nThông tin về sự ra đi của...
# 181  2024-01-04T08:30:00  Tối 30.12.2023, tại Quảng trường - Công viên K...
# 182  2024-07-16T18:21:00  Vụ việc Đàm Vĩnh Hưng bị cấm diễn gây xôn xao ...
#
#                                                 Source
# 0    https://thanhnien.vn/tong-bi-thu-nguyen-phu-tr...
# 1    https://thanhnien.vn/trieu-tien-my-va-lhq-gui-...
# 2    https://thanhnien.vn/quan-diem-cua-tong-bi-thu...
# 3    https://thanhnien.vn/cuba-tuyen-bo-quoc-tang-t...
# 4    https://thanhnien.vn/tong-bi-thu-nguyen-phu-tr...
# ..                                                 ...
# 178  https://thanhnien.vn/su-khac-biet-khien-ben-af...
# 179  https://thanhnien.vn/dong-thai-cua-thanh-hang-...
# 180  https://thanhnien.vn/vua-vo-thuat-vuong-vu-qua...
# 181  https://thanhnien.vn/chuong-trinh-nghe-thuat-c...
# 182  https://thanhnien.vn/dam-vinh-hung-co-lich-di-...
#
# [183 rows x 3 columns]
