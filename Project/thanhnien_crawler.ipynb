# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://thanhnien.vn', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://thanhnien.vn")
# Out:
# Co tat ca 928 den tu https://thanhnien.vn

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong thanhnien")
# Out:
# Xuat hien 928 bai bao trong thanhnien

# %%
head = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  try:
    vnex_url.download()
    vnex_url.parse()
    date = vnex_url.meta_data['article']['published_time']
  except Exception:
    pass
  else:
    row = [date,vnex_url.text,vnex_url.url]
    head = np.append(head, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(head,(head.size//3,3))
filename = 'thanhnien_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                     Date                                            Content  \
# 0    2024-07-24T15:00:00  Nghệ nhân phải có cốt cách riêng!\r\n\r\nNgoài...
# 1    2024-07-24T15:18:00  Sáng 24.7, ông Hồ Triệu Minh, người phát ngôn ...
# 2    2024-07-24T14:59:00  Đại diện Cục Cảnh sát quản lý hành chính về tr...
# 3    2024-07-24T15:00:00  Ngày 24.7, lãnh đạo cấp cao các nước ASEAN ra ...
# 4    2024-07-24T17:26:00  Theo Công an TP.Hà Nội, trong 2 ngày 25 và 26....
# ..                   ...                                                ...
# 869  2023-12-28T07:14:00  ViGPT phiên bản cộng đồng là một "ChatGPT phiê...
# 870  2023-11-13T22:52:00  Bộ sưu tập 100 tác phẩm bình gốm có điêu khắc ...
# 871  2023-10-20T09:33:00  Lạc quan trước nghịch cảnh\r\n\r\nTháng 10.201...
# 872  2024-07-24T18:07:00  Kem mắt Image Skincare có thật sự tốt không mà...
# 873  2024-07-24T18:00:00  \r\n\r\n\r\n\r\nBệnh viện đa khoa Sài Gòn Phan...
#
#                                                 Source
# 0    https://thanhnien.vn/ky-uc-khong-quen-ve-mot-l...
# 1    https://thanhnien.vn/nhieu-doan-quoc-te-du-tan...
# 2    https://thanhnien.vn/nguoi-dan-co-the-online-g...
# 3    https://thanhnien.vn/asean-ra-tuyen-bo-chung-c...
# 4    https://thanhnien.vn/nhung-tuyen-duong-bi-cam-...
# ..                                                 ...
# 869  https://thanhnien.vn/vinbigdata-ra-mat-ban-cha...
# 870  https://thanhnien.vn/ngam-100-hinh-tuong-rong-...
# 871  https://thanhnien.vn/me-tre-mac-ung-thu-truyen...
# 872  https://thanhnien.vn/review-kem-mat-image-skin...
# 873  https://thanhnien.vn/chua-tri-benh-nhan-bi-man...
#
# [874 rows x 3 columns]
