# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://thanhnien.vn', language = 'vi', memoize_articles = False, follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://thanhnien.vn")
# Out:
# Co tat ca 929 den tu https://thanhnien.vn

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong thanhnien")
# Out:
# Xuat hien 929 bai bao trong thanhnien

# %%
head = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  try:
    vnex_url.download()
    vnex_url.parse()
    date = vnex_url.meta_data['article']['published_time']
  except Exception:
    pass
  else:
    row = [date,vnex_url.text,vnex_url.url]
    head = np.append(head, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(head,(head.size//3,3))
filename = 'thanhnien_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                   Date                                            Content  \
# 0  2024-07-19T18:06:00  Theo thông tin từ Hội đồng chuyên môn bảo vệ s...
# 1  2024-07-19T16:43:00  Bàn cờ của những nước lớn\r\n\r\nTừ mùa hè năm...
# 2  2024-07-19T20:48:00  Chiều 19.7, tại tỉnh Hậu Giang, Bộ Công an phố...
# 3  2024-07-19T21:17:00  Theo công bố của VFF, để tạo điều kiện cho các...
# 4  2024-07-19T17:38:00  Thí sinh tham dự kỳ thi tốt nghiệp THPT năm na...
# 5  2024-07-19T18:21:00  Hội đồng tuyển sinh đại học chính quy Trường Đ...
# 6  2024-07-19T17:38:00  Phó giám đốc Sở Y tế TP.HCM Nguyễn Văn Vĩnh Ch...
# 7  2024-07-19T16:22:00  Tại Đối thoại tháng 7 về nâng hạng, gọi vốn và...
# 8  2024-07-19T16:50:00  Ông Nguyễn Hoàng Quân, Giám đốc Trung tâm Tư v...
# 9  2024-07-19T16:39:00  Cơ quan Cảnh sát điều tra Công an TP.Hà Nội vừ...
#
#                                               Source
# 0  https://thanhnien.vn/tong-bi-thu-nguyen-phu-tr...
# 1  https://thanhnien.vn/hiep-dinh-geneva-thang-lo...
# 2  https://thanhnien.vn/bo-cong-an-khen-thuong-72...
# 3  https://thanhnien.vn/v-league-vff-ra-phan-quye...
# 4  https://thanhnien.vn/diem-san-truong-dh-luat-t...
# 5  https://thanhnien.vn/truong-dh-khoa-hoc-tu-nhi...
# 6  https://thanhnien.vn/tphcm-tang-cuong-phong-ch...
# 7  https://thanhnien.vn/ngan-hang-nha-nuoc-noi-gi...
# 8  https://thanhnien.vn/them-hang-loat-nganh-co-d...
# 9  https://thanhnien.vn/dien-bien-moi-vu-an-cuu-c...
