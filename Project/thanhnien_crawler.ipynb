# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://thanhnien.vn', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://thanhnien.vn")
# Out:
# Co tat ca 150 den tu https://thanhnien.vn

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong thanhnien")
# Out:
# Xuat hien 150 bai bao trong thanhnien

# %%
head = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  try:
    vnex_url.download()
    vnex_url.parse()
    date = vnex_url.meta_data['article']['published_time']
  except Exception:
    pass
  else:
    row = [date,vnex_url.text,vnex_url.url]
    head = np.append(head, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(head,(head.size//3,3))
filename = 'thanhnien_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                     Date                                            Content  \
# 0    2024-07-27T06:30:00  Thực hiện Hiệp ước hoạch định biên giới Quốc g...
# 1    2024-07-27T08:00:00  Chỉ cần cung cấp những thông tin cơ bản về họ ...
# 2    2024-07-27T06:20:00  Có kịp khai thác vào tháng 11?\r\n\r\nVăn phòn...
# 3    2024-07-27T06:18:00  Mua bán nhà ở trong tương lai minh bạch, rõ rà...
# 4    2024-07-27T07:33:00  Kính cẩn nghiêng mình tưởng nhớ các liệt sĩ\r\...
# ..                   ...                                                ...
# 144  2024-07-26T16:29:00  Thí sinh trúng tuyển làm thủ tục nhập học năm ...
# 145  2024-07-22T13:16:00  Sáng nay 22.7, Trường ĐH Y Hà Nội đã thông báo...
# 146  2024-07-27T08:07:00  Tại miền Bắc, giá heo hơi cao nhất 66.000 đồng...
# 147  2024-07-27T08:00:00  Lấy cảm hứng từ tình cảm trong văn hóa ‘tình’ ...
# 148  2024-07-27T08:00:00  Giải bơi SeaStar Nha Trang Bay 2024 dự kiến th...
#
#                                                 Source
# 0    https://thanhnien.vn/nga-xuong-khi-khong-mang-...
# 1    https://thanhnien.vn/tham-nhap-thi-truong-hoc-...
# 2    https://thanhnien.vn/metro-so-1-tien-sat-ve-di...
# 3    https://thanhnien.vn/nguoi-mua-nha-se-khong-co...
# 4    https://thanhnien.vn/nghia-tinh-thang-bay-than...
# ..                                                 ...
# 144  https://thanhnien.vn/thi-sinh-chi-rot-dai-hoc-...
# 145  https://thanhnien.vn/diem-san-nhieu-nganh-bac-...
# 146  https://thanhnien.vn/gia-heo-hoi-hom-nay-27720...
# 147  https://thanhnien.vn/chocopie-cong-bo-top-2-ch...
# 148  https://thanhnien.vn/khanh-hoa-to-chuc-giai-bo...
#
# [149 rows x 3 columns]
