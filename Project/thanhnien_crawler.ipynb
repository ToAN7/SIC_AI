# %% [markdown]
# # 1. Tải và cài đặt một số thư viện cho crawler

# %%
import numpy as np
import pandas as pd
import csv
import newspaper
from newspaper import Article as Atc
from newspaper import Source as Scr

# %% [markdown]
# # 2. Tải tất cả đường link và lọc ra những đường link chỉ chứa html:

# %%
vnex_paper = newspaper.build('https://thanhnien.vn', language = 'vi', follow_meta_refresh = True, keep_article_html=True)

# %%
size = vnex_paper.size()
print(f"Co tat ca {size} den tu https://thanhnien.vn")
# Out:
# Co tat ca 173 den tu https://thanhnien.vn

# %%
valid_url = np.array([],np.string_)
for i in range(size):
  vnex_url = vnex_paper.article_urls()[i]
  temp = ''
  for j in range(len(vnex_url)):
    temp = vnex_url[len(vnex_url) - j - 1] + temp
    if temp == 'htm' or temp == 'html':
      valid_url = np.append(valid_url,vnex_url)
print(f"Xuat hien {np.shape(valid_url)[0]} bai bao trong thanhnien")
# Out:
# Xuat hien 173 bai bao trong thanhnien

# %%
head = np.array(['Date', 'Content', 'Source'],np.string_)
for i in range(np.shape(valid_url)[0]):
  vnex_url = Atc(valid_url[i],language = 'vi')
  try:
    vnex_url.download()
    vnex_url.parse()
    date = vnex_url.meta_data['article']['published_time']
  except Exception:
    pass
  else:
    row = [date,vnex_url.text,vnex_url.url]
    head = np.append(head, row, axis = 0)

# %% [markdown]
# # 3. Lưu lại dữ liệu với định dạng Date,Content,Source:

# %%
star = np.reshape(head,(head.size//3,3))
filename = 'thanhnien_vi.csv'

# %%
with open(filename, 'a') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter='|', quoting= csv.QUOTE_ALL)
    csvWriter.writerows(star)

# %%
df = pd.read_csv(filename,delimiter='|')
print(df)
# Out:
#                     Date                                            Content  \
# 0    2024-07-21T11:32:00  Trong cuộc đời ngoại giao của mình, tôi có may...
# 1    2024-07-21T08:44:00  Ông Phan Văn Kính (82 tuổi), nguyên Giám đốc Đ...
# 2    2024-07-21T09:57:00  Ngay sau khi được tin Tổng Bí thư Nguyễn Phú T...
# 3    2024-07-21T09:00:00  Khoảng 7 giờ, vị trí tâm bão ở vào khoảng 16,...
# 4    2024-07-21T11:36:00  Không ai thúc giục, một cách tự nguyện, hàng l...
# ..                   ...                                                ...
# 166  2024-07-20T23:34:00                                                NaN
# 167  2024-07-16T20:51:00  Như Thanh Niên đã thông tin, sao chổi C/2023 A...
# 168  2024-07-21T07:00:00  Ngày 20.7, tại TP.Biên Hòa (Đồng Nai), T.Ư Hội...
# 169  2023-12-17T15:12:00  Sau khi tốt nghiệp tại Trường ĐH Kinh tế - Luậ...
# 170  2024-06-27T18:14:00  Đến thăm đội sinh viên tình nguyện tham gia Ti...
#
#                                                 Source
# 0    https://thanhnien.vn/tong-bi-thu-xan-tay-cung-...
# 1    https://thanhnien.vn/toi-goi-gon-hai-tu-de-ngh...
# 2    https://thanhnien.vn/bao-chi-quoc-te-viet-ve-t...
# 3    https://thanhnien.vn/ap-thap-nhiet-doi-tren-bi...
# 4    https://thanhnien.vn/nguoi-tre-thay-anh-dai-di...
# ..                                                 ...
# 166  https://thanhnien.vn/tu-vi-hang-ngay-xem-tu-vi...
# 167  https://thanhnien.vn/sao-choi-duoc-cho-ngam-ba...
# 168  https://thanhnien.vn/nhieu-giai-phap-chuyen-do...
# 169  https://thanhnien.vn/co-gai-nghi-viec-luong-30...
# 170  https://thanhnien.vn/bi-thu-tu-doan-nguyen-pha...
#
# [171 rows x 3 columns]
